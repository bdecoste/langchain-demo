# %%
# %run -i chat-chinook-interactive.py
# Out:
# Please enter message:
#  What albums has Rush released?
# ================================ Human Message =================================
#
# What albums has Rush released?
# ================================== Ai Message ==================================
#
# [{'text': "I'll query the database to find albums released by Rush.", 'type': 'text'}, {'id': 'toolu_01HZybGesCdRB9wCgp7sNN3t', 'caller': {'type': 'direct'}, 'input': {'query': "SELECT a.title AS album, b.name AS band FROM albums a JOIN bands b ON a.band_id = b.id WHERE b.name = 'Rush' ORDER BY a.release_year;"}, 'name': 'sql_query', 'type': 'tool_use'}]
# Tool Calls:
#   sql_query (toolu_01HZybGesCdRB9wCgp7sNN3t)
#  Call ID: toolu_01HZybGesCdRB9wCgp7sNN3t
#   Args:
#     query: SELECT a.title AS album, b.name AS band FROM albums a JOIN bands b ON a.band_id = b.id WHERE b.name = 'Rush' ORDER BY a.release_year;
# ================================= Tool Message =================================
# Name: sql_query
#
# ...
